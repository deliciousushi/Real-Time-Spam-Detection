# %% [markdown]
# <a href="https://colab.research.google.com/github/deliciousushi/Real-Time-Spam-Detection/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPORT NECESSARY LIBRARIES**

# %%
import nltk
from nltk. tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from math import log, sqrt
import pandas as pd
import numpy as np
import re
# %matplotlib inline

# %% [markdown]
# **READ DATASET**

# %%
mails = pd.read_csv('emails.csv', encoding = 'latin-1')
mails. head()
# Out:
#                                                 Text  Spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %% [markdown]
# # **DATA PREPROCESSING**

# %% [markdown]
# **SEE IF THERE'S NULL VALUE**

# %%
null_values = mails.isnull()
null_count = mails.isnull().sum()
print(null_count)
# Out:
# Text    0
# Spam    0
# dtype: int64

# %%
# Renaming the columns
mails.columns = ["Message", "Category"]

print(mails)
# Out:
#                                                 Message  Category
# 0     Subject: naturally irresistible your corporate...         1
# 1     Subject: the stock trading gunslinger  fanny i...         1
# 2     Subject: unbelievable new homes made easy  im ...         1
# 3     Subject: 4 color printing special  request add...         1
# 4     Subject: do not have money , get software cds ...         1
# ...                                                 ...       ...
# 5723  Subject: re : research and development charges...         0
# 5724  Subject: re : receipts from visit  jim ,  than...         0
# 5725  Subject: re : enron case study update  wow ! a...         0
# 5726  Subject: re : interest  david ,  please , call...         0
# 5727  Subject: news : aurora 5 . 2 update  aurora ve...         0
#
# [5728 rows x 2 columns]

# %%
mails.shape
# Out:
# (5728, 2)

# %%
#drop un necessary catagory labels

unique_labels = mails['Category'].unique()
print("Unique labels in 'Category' column:", unique_labels)
# Out:
# Unique labels in 'Category' column: [1 0]

# %%
mails = mails[mails['Category'].isin([0, 1])]
print(mails)
# Out:
#                                                 Message  Category
# 0     Subject: naturally irresistible your corporate...         1
# 1     Subject: the stock trading gunslinger  fanny i...         1
# 2     Subject: unbelievable new homes made easy  im ...         1
# 3     Subject: 4 color printing special  request add...         1
# 4     Subject: do not have money , get software cds ...         1
# ...                                                 ...       ...
# 5723  Subject: re : research and development charges...         0
# 5724  Subject: re : receipts from visit  jim ,  than...         0
# 5725  Subject: re : enron case study update  wow ! a...         0
# 5726  Subject: re : interest  david ,  please , call...         0
# 5727  Subject: news : aurora 5 . 2 update  aurora ve...         0
#
# [5728 rows x 2 columns]

# %%
#duplicate value handling

mails.duplicated().sum()
# Out:
# 33

# %%
mails = mails.drop_duplicates(keep='first')

# %%
mails.duplicated().sum()
# Out:
# 0

# %%
mails.shape
# Out:
# (5695, 2)

# %%
mails['Category'].value_counts()
# Out:
# Category
# 0    4327
# 1    1368
# Name: count, dtype: int64

# %% [markdown]
# ## **EDA**

# %%
mails
# Out:
#                                                 Message  Category
# 0     Subject: naturally irresistible your corporate...         1
# 1     Subject: the stock trading gunslinger  fanny i...         1
# 2     Subject: unbelievable new homes made easy  im ...         1
# 3     Subject: 4 color printing special  request add...         1
# 4     Subject: do not have money , get software cds ...         1
# ...                                                 ...       ...
# 5723  Subject: re : research and development charges...         0
# 5724  Subject: re : receipts from visit  jim ,  than...         0
# 5725  Subject: re : enron case study update  wow ! a...         0
# 5726  Subject: re : interest  david ,  please , call...         0
# 5727  Subject: news : aurora 5 . 2 update  aurora ve...         0
#
# [5695 rows x 2 columns]

# %%
category_counts = mails['Category'].value_counts()

# %%
mails
# Out:
#                                                 Message  Category
# 0     Subject: naturally irresistible your corporate...         1
# 1     Subject: the stock trading gunslinger  fanny i...         1
# 2     Subject: unbelievable new homes made easy  im ...         1
# 3     Subject: 4 color printing special  request add...         1
# 4     Subject: do not have money , get software cds ...         1
# ...                                                 ...       ...
# 5723  Subject: re : research and development charges...         0
# 5724  Subject: re : receipts from visit  jim ,  than...         0
# 5725  Subject: re : enron case study update  wow ! a...         0
# 5726  Subject: re : interest  david ,  please , call...         0
# 5727  Subject: news : aurora 5 . 2 update  aurora ve...         0
#
# [5695 rows x 2 columns]

# %%
# Plot a pie chart
plt.figure(figsize=(8, 6))
plt.pie(category_counts, labels=category_counts.index, autopct='%0.2f%%', startangle=140)
plt.title('Distribution of Ham and Spam Messages')
plt.show()

# %%
# Plot bar chart
bars=plt.bar(category_counts.index, category_counts.values, color=['blue', 'orange'])
plt.title('Frequency of Categories')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.grid(axis='y')  # Add gridlines on y-axis for clarity
for bar, label in zip(bars, category_counts.index):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.3, label, ha='center', va='bottom')

plt.show()

# %% [markdown]
# **TRAIN-TEST SPLIT**

# %%
mails.head()
# Out:
#                                              Message  Category
# 0  Subject: naturally irresistible your corporate...         1
# 1  Subject: the stock trading gunslinger  fanny i...         1
# 2  Subject: unbelievable new homes made easy  im ...         1
# 3  Subject: 4 color printing special  request add...         1
# 4  Subject: do not have money , get software cds ...         1

# %%
from sklearn.model_selection import train_test_split

X = mails['Message']
y = mails['Category']

X_train_raw, X_test_raw, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

# %%
X_test_raw
# Out:
# 2036    Subject: enron research and ebs engineering an...
# 3766    Subject: re : summer associate mentor  ginger ...
# 4935    Subject: re : var for metals  ted , anjam ' s ...
# 3175    Subject: briefing robert johnston on metals  v...
# 21      Subject: re : wearable electronics  hi my name...
#                               ...
# 1134    Subject: 25 mmg works wonders  how to save on ...
# 2015    Subject: a letter i sent  fiona ,  ?  i sent y...
# 678     Subject: important : $ 97438  dear homeowner ,...
# 1287    Subject: how to soak her in cum  " my girlfrie...
# 3466    Subject: re : ebs var transaction policy  that...
# Name: Message, Length: 1139, dtype: object

# %%
X_train_raw.shape
# Out:
# (4556,)

# %%
X_test_raw.shape
# Out:
# (1139,)

# %% [markdown]
# **PRE-PROCESSING TRAINING DATA**

# %%
from sklearn.feature_extraction.text import CountVectorizer

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
spam_words = ' '.join(mails[mails['Category'] == 1]['Message'])

# Generate WordCloud
spam_wc = WordCloud(width=512, height=512).generate(spam_words)

# Plotting
plt.figure(figsize=(6, 4))  # Adjust the figure size as needed
plt.imshow(spam_wc, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
ham_words = ' '.join(mails[mails['Category'] == 0]['Message'])

# Generate WordCloud
ham_wc = WordCloud(width=512, height=512).generate(ham_words)

# Plotting
plt.figure(figsize=(6, 4))  # Adjust the figure size as needed
plt.imshow(ham_wc, interpolation='bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
def process_text(text):

    # Initialize stemmer and stopwords
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words('english'))

    # Remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Convert to lowercase
    text = text.lower()

    # Tokenize
    tokens = word_tokenize(text)

    # Remove stopwords and stem
    stemmed_tokens = [stemmer.stem(token) for token in tokens if token not in stop_words]

    # Return processed text as a single string
    processed_text = ' '.join(stemmed_tokens)

    return processed_text

# %%
# Process text data for both training sets
X_train = X_train_raw.apply(process_text)

# %%
X_train
# Out:
# 165     subject new love tab shop visit llcens onlin d...
# 3606    subject ca henwood engag bonni thank get back ...
# 5670    subject datren william accept fyi forward stin...
# 394     subject upsid pressur signal institut interest...
# 1179    subject reason sh op zone sav ving run short t...
#                               ...
# 905     subject know compani lt realli hard recollect ...
# 5213    subject transit research group updat molli sur...
# 3994    subject time prc time administ research group ...
# 235     subject return mail see transcript detail orig...
# 5177    subject typeset version vinc attach copi types...
# Name: Message, Length: 4556, dtype: object

# %%
# Vectorize using CountVectorizer
vectorizer = CountVectorizer()
X_train = vectorizer.fit_transform(X_train)

# %%
X_train
# Out:
# <4556x23054 sparse matrix of type '<class 'numpy.int64'>'
# 	with 380504 stored elements in Compressed Sparse Row format>

# %%
y_train
# Out:
# 165     1
# 3606    0
# 5670    0
# 394     1
# 1179    1
#        ..
# 905     1
# 5213    0
# 3994    0
# 235     1
# 5177    0
# Name: Category, Length: 4556, dtype: int64

# %% [markdown]
# **TRAIN MODEL ON TRAINING SET**

# %%
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score, f1_score
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform labels
y_train= label_encoder.fit_transform(y_train)

# %%
import seaborn as sns

# Convert to DataFrame for visualization
X_train_df = pd.DataFrame(X_train.toarray(), columns=vectorizer.get_feature_names_out())

# Plotting the heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(X_train_df, cmap='YlGnBu', annot=False)
plt.title('Heatmap of Term Frequencies in Training Data')
plt.xlabel('Terms')
plt.ylabel('Documents')
plt.show()

# %%
#Training naive bayes model
nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
#Training svm model
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
#Training random forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#Training logistic regression
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# **TESTING TEXT DATA FROM TESTSET**

# %%
X_test = X_test_raw.apply(process_text)
X_test = vectorizer.transform(X_test)

# %%
# Predictions
svm_pred = svm_model.predict(X_test)
nb_pred = nb_model.predict(X_test)
rf_pred = rf_model.predict(X_test)
lr_pred = lr_model.predict(X_test)

# %%
label_encoder = LabelEncoder()
# Fit and transform labels
y_test= label_encoder.fit_transform(y_test)

# %%
y_test
# Out:
# array([0, 0, 0, ..., 1, 1, 0])

# %%
# Define a function to evaluate each model and print metrics
def evaluate_model(model, X_test, y_test):
    # Predictions
    y_pred = model.predict(X_test)

    # Accuracy
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy: {accuracy}")

    # Precision
    precision = precision_score(y_test, y_pred, average='weighted')
    print(f"Precision: {precision}")

    # Recall
    recall = recall_score(y_test, y_pred, average='weighted')
    print(f"Recall: {recall}")

    # F1 Score
    f1 = f1_score(y_test, y_pred, average='weighted')
    print(f"F1 Score: {f1}")

    # Classification Report
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

# %%
# Evaluate SVM model
print("Support Vector Machine (SVM):")
evaluate_model(svm_model, X_test, y_test)

# Evaluate Naive Bayes model
print("Naive Bayes:")
evaluate_model(nb_model, X_test, y_test)

# Evaluate Random Forest model
print("Random Forest:")
evaluate_model(rf_model, X_test, y_test)

# Evaluate Logistic Regression model
print("Logistic Regression:")
evaluate_model(lr_model, X_test, y_test)
# Out:
# Support Vector Machine (SVM):
# Accuracy: 0.9885864793678666
# Precision: 0.9885619511818375
# Recall: 0.9885864793678666
# F1 Score: 0.9885648179024351
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       866
#            1       0.98      0.97      0.98       273
#
#     accuracy                           0.99      1139
#    macro avg       0.99      0.98      0.98      1139
# weighted avg       0.99      0.99      0.99      1139
#
# Naive Bayes:
# Accuracy: 0.9938542581211589
# Precision: 0.993864030142277
# Recall: 0.9938542581211589
# F1 Score: 0.9938581006012718
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       866
#            1       0.99      0.99      0.99       273
#
#     accuracy                           0.99      1139
#    macro avg       0.99      0.99      0.99      1139
# weighted avg       0.99      0.99      0.99      1139
#
# Random Forest:
# Accuracy: 0.974539069359087
# Precision: 0.975027184244381
# Recall: 0.974539069359087
# F1 Score: 0.9741093417344583
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       866
#            1       0.99      0.90      0.94       273
#
#     accuracy                           0.97      1139
#    macro avg       0.98      0.95      0.96      1139
# weighted avg       0.98      0.97      0.97      1139
#
# Logistic Regression:
# Accuracy: 0.9947322212467077
# Precision: 0.9947322212467077
# Recall: 0.9947322212467077
# F1 Score: 0.9947322212467077
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       866
#            1       0.99      0.99      0.99       273
#
#     accuracy                           0.99      1139
#    macro avg       0.99      0.99      0.99      1139
# weighted avg       0.99      0.99      0.99      1139
